# %% [markdown]
# # AdaFace ONNX Evaluation
# This notebook evaluates a pretrained `best_adaface.onnx` model by extracting embeddings and computing cosine similarity on your dataset.

# %%
# !pip install onnxruntime-gpu opencv-python scikit-learn tqdm matplotlib
# Out:
# Requirement already satisfied: onnxruntime-gpu in .\backend\.venv\Lib\site-packages (1.28.0)
# Requirement already satisfied: opencv-python in .\backend\.venv\Lib\site-packages (5.0.0.93)
# Requirement already satisfied: scikit-learn in .\backend\.venv\Lib\site-packages (1.9.0)
# Requirement already satisfied: tqdm in .\backend\.venv\Lib\site-packages (4.70.0)
# Requirement already satisfied: matplotlib in .\backend\.venv\Lib\site-packages (3.11.1)
# Requirement already satisfied: flatbuffers in .\backend\.venv\Lib\site-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in .\backend\.venv\Lib\site-packages (from onnxruntime-gpu) (2.4.6)
# Requirement already satisfied: packaging in .\backend\.venv\Lib\site-packages (from onnxruntime-gpu) (26.3)
# Requirement already satisfied: protobuf>=4.25.8 in .\backend\.venv\Lib\site-packages (from onnxruntime-gpu) (7.35.1)
# Requirement already satisfied: scipy>=1.10.0 in .\backend\.venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in .\backend\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in .\backend\.venv\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\backend\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in .\backend\.venv\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in .\backend\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\backend\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\backend\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\backend\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=9 in .\backend\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\backend\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\backend\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\backend\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import numpy as np
import onnxruntime as ort
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm

# %%
MODEL_PATH='best_adaface.onnx'

session=ort.InferenceSession(
    MODEL_PATH,
    providers=['CUDAExecutionProvider','CPUExecutionProvider']
)

print("Input :",session.get_inputs()[0].name)
print("Shape :",session.get_inputs()[0].shape)
print("Output:",session.get_outputs()[0].name)
print("Shape :",session.get_outputs()[0].shape)
# Out:
# C:\Users\taran\Documents\GitHub\vizage\backend\.venv\Lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:153: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# ---------------------------------------------------------------------------
# NoSuchFile                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 MODEL_PATH='best_adaface.onnx'
#       2
# ----> 3 session=ort.InferenceSession(
#       4     MODEL_PATH,
#       5     providers=['CUDAExecutionProvider','CPUExecutionProvider']
#       6 )
#
# File ~\Documents\GitHub\vizage\backend\.venv\Lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:534, in InferenceSession.__init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     531 disabled_optimizers = kwargs.get("disabled_optimizers")
#     533 try:
# --> 534     self._create_inference_session(providers, provider_options, disabled_optimizers)
#     535 except (ValueError, RuntimeError) as e:
#     536     if self._enable_fallback:
#
# File ~\Documents\GitHub\vizage\backend\.venv\Lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:629, in InferenceSession._create_inference_session(self, providers, provider_options, disabled_optimizers)
#     626 self._register_ep_custom_ops(session_options, providers, provider_options, available_providers)
#     628 if self._model_path:
# --> 629     sess = C.InferenceSession(session_options, self._model_path, True, self._read_config_from_model)
#     630 else:
#     631     sess = C.InferenceSession(session_options, self._model_bytes, False, self._read_config_from_model)
#
# NoSuchFile: [ONNXRuntimeError] : 3 : NO_SUCHFILE : Load model from best_adaface.onnx failed:Load model best_adaface.onnx failed. File doesn't exist

# %%
def preprocess(path,size=(112,112)):
    img=cv2.imread(str(path))
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img=cv2.resize(img,size)
    img=img.astype(np.float32)
    img=(img/255.0-0.5)/0.5
    img=np.transpose(img,(2,0,1))
    img=np.expand_dims(img,0)
    return img

# %%
input_name=session.get_inputs()[0].name
output_name=session.get_outputs()[0].name

def embedding(image_path):
    x=preprocess(image_path)
    emb=session.run([output_name],{input_name:x})[0]
    emb=emb/np.linalg.norm(emb)
    return emb

# %%
# Change this path
DATASET=Path("../datasets/CV Dataset/Ankit-CV Dataset")

people={}
for person in DATASET.iterdir():
    if person.is_dir():
        people[person.name]=list(person.rglob("*.jpg"))

print("People:",len(people))
print(next(iter(people.items())))

# %%
# Example: compare two images of same identity
person=list(people.keys())[0]
imgs=people[person]

emb1=embedding(imgs[0])
emb2=embedding(imgs[1])

score=cosine_similarity(emb1,emb2)[0][0]
print("Identity:",person)
print("Similarity:",score)

# %%
# Compare different identities
names=list(people.keys())

emb1=embedding(people[names[0]][0])
emb2=embedding(people[names[1]][0])

score=cosine_similarity(emb1,emb2)[0][0]

print(names[0],"vs",names[1])
print(score)

# %% [markdown]
# ## Next Step
#
# If the ONNX model outputs 512-dimensional embeddings and the similarity scores behave as expected (same-identity scores consistently higher than different-identity scores), the model is likely functioning correctly. You can then extend this notebook to evaluate all image pairs and compute ROC, EER, FAR/FRR, and overall verification accuracy.
